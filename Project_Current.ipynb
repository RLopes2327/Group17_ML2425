# %% [markdown]
# **Table of Contents** <br>
#
# * [1.Import Libraries](#importlibraries)
# * [2.Import Dataset](#importdataset)
# * [3.Initial Analysis](#initialanalysis)
# * [4. Data Pre-Processing](#datapreprocessing)
#     * [4.1 Data Partition](#datapartition)
#     * [4.2 Missing Values](#missingvalues)

# %% [markdown]
# <hr>
# <a class="anchor" id="importlibraries">
#
# # 1. Import libraries
#
# </a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

#data partition
from sklearn.model_selection import train_test_split

#empty values
import missingno as msno

#filter methods
# spearman 
# chi-square
import scipy.stats as stats
from scipy.stats import chi2_contingency

#wrapper methods
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.feature_selection import RFE

# embedded methods
from sklearn.linear_model import LassoCV

#
from math import ceil

#scaler
from sklearn.preprocessing import MinMaxScaler

from sklearn.metrics import confusion_matrix

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <hr>
# <a class="anchor" id="importdataset">
#
# # 2. Import Dataset
#
# </a>

# %%
train = pd.read_csv('train_data.csv')
test = pd.read_csv('test_data.csv')
sample_submission = pd.read_csv('sample_submission.csv')

# %% [markdown]
# <hr>
# <a class="anchor" id="initialanalysis">
#
# # 3. Initial Analysis
#
# </a>

# %%
train.head(20)
# Out:
#    Accident Date  Age at Injury Alternative Dispute Resolution Assembly Date  \
# 0     2019-12-30           31.0                              N    2020-01-01
# 1     2019-08-30           46.0                              N    2020-01-01
# 2     2019-12-06           40.0                              N    2020-01-01
# 3            NaN            NaN                            NaN    2020-01-01
# 4     2019-12-30           61.0                              N    2020-01-01
# 5     2019-12-26           67.0                              N    2020-01-01
# 6     2019-12-28           48.0                              N    2020-01-01
# 7     2019-12-30           33.0                              N    2020-01-01
# 8     2019-12-23           55.0                              N    2020-01-01
# 9     2019-12-29           20.0                              N    2020-01-01
# 10    2019-12-28           48.0                              N    2020-01-01
# 11    2019-12-14           21.0                              N    2020-01-01
# 12    2019-12-26           51.0                              N    2020-01-01
# 13    2019-08-26           62.0                              N    2020-01-01
# 14    2019-12-19           35.0                              N    2020-01-01
# 15    2019-12-18           54.0                              N    2020-01-01
# 16    2019-12-28           32.0                              N    2020-01-01
# 17    2019-12-19           34.0                              N    2020-01-01
# 18    2019-12-18           55.0                              N    2020-01-01
# 19    2019-12-29           55.0                              N    2020-01-01
#
#    Attorney/Representative  Average Weekly Wage  Birth Year    C-2 Date  \
# 0                        N                 0.00      1988.0  2019-12-31
# 1                        Y              1745.93      1973.0  2020-01-01
# 2                        N              1434.80      1979.0  2020-01-01
# 3                      NaN                  NaN         NaN         NaN
# 4                        N                  NaN      1958.0  2019-12-31
# 5                        N                 0.00      1952.0  2019-12-31
# 6                        N                 0.00      1971.0  2019-12-31
# 7                        N                 0.00      1986.0  2019-12-31
# 8                        N                 0.00      1964.0  2020-01-01
# 9                        N               225.00         NaN  2019-12-31
# 10                       N                 0.00      1971.0  2019-12-31
# 11                       N                 0.00         0.0  2019-12-31
# 12                       N                 0.00         NaN  2020-01-01
# 13                       N                 0.00      1956.0  2020-01-01
# 14                       N               512.95      1984.0  2019-12-31
# 15                       Y              1718.78      1965.0  2019-12-31
# 16                       N                 0.00      1987.0  2020-01-01
# 17                       Y              1682.39      1985.0  2020-01-01
# 18                       Y               665.45      1964.0  2019-12-31
# 19                       N                 0.00      1964.0  2019-12-31
#
#       C-3 Date                  Carrier Name  ... WCIO Cause of Injury Code  \
# 0          NaN    NEW HAMPSHIRE INSURANCE CO  ...                      27.0
# 1   2020-01-14  ZURICH AMERICAN INSURANCE CO  ...                      97.0
# 2          NaN     INDEMNITY INSURANCE CO OF  ...                      79.0
# 3          NaN                           NaN  ...                       NaN
# 4          NaN          STATE INSURANCE FUND  ...                      16.0
# 5          NaN   INDEMNITY INS. OF N AMERICA  ...                      31.0
# 6          NaN             LM INSURANCE CORP  ...                      19.0
# 7   2020-03-04          STATE INSURANCE FUND  ...                      99.0
# 8          NaN      ROCHESTER, UNIVERSITY OF  ...                      99.0
# 9          NaN             LM INSURANCE CORP  ...                      81.0
# 10         NaN    NEW HAMPSHIRE INSURANCE CO  ...                      81.0
# 11         NaN   INDEMNITY INS. OF N AMERICA  ...                      75.0
# 12         NaN   INDEMNITY INS. OF N AMERICA  ...                       1.0
# 13         NaN  AMERICAN ZURICH INSURANCE CO  ...                      45.0
# 14         NaN             LM INSURANCE CORP  ...                      56.0
# 15  2020-03-04   INDEMNITY INS. OF N AMERICA  ...                      56.0
# 16         NaN   INDEMNITY INS. OF N AMERICA  ...                      53.0
# 17  2020-01-07         NYC TRANSIT AUTHORITY  ...                      99.0
# 18         NaN     WAL-MART ASSOCIATES, INC.  ...                      29.0
# 19         NaN   INDEMNITY INS. OF N AMERICA  ...                      81.0
#
#                WCIO Cause of Injury Description WCIO Nature of Injury Code  \
# 0                  FROM LIQUID OR GREASE SPILLS                       10.0
# 1                             REPETITIVE MOTION                       49.0
# 2                OBJECT BEING LIFTED OR HANDLED                        7.0
# 3                                           NaN                        NaN
# 4               HAND TOOL, UTENSIL; NOT POWERED                       43.0
# 5                       FALL, SLIP OR TRIP, NOC                       10.0
# 6                    CUT, PUNCTURE, SCRAPE, NOC                       40.0
# 7                    OTHER - MISCELLANEOUS, NOC                       71.0
# 8                    OTHER - MISCELLANEOUS, NOC                       59.0
# 9                        STRUCK OR INJURED, NOC                       59.0
# 10                       STRUCK OR INJURED, NOC                       10.0
# 11                     FALLING OR FLYING OBJECT                       37.0
# 12                                    CHEMICALS                        4.0
# 13  COLLISION OR SIDESWIPE WITH ANOTHER VEHICLE                       52.0
# 14                                      LIFTING                       52.0
# 15                                      LIFTING                       49.0
# 16                                     TWISTING                       52.0
# 17                   OTHER - MISCELLANEOUS, NOC                       49.0
# 18                                ON SAME LEVEL                       10.0
# 19                       STRUCK OR INJURED, NOC                       40.0
#
#              WCIO Nature of Injury Description WCIO Part Of Body Code  \
# 0                                    CONTUSION                   62.0
# 1                               SPRAIN OR TEAR                   38.0
# 2                                   CONCUSSION                   10.0
# 3                                          NaN                    NaN
# 4                                     PUNCTURE                   36.0
# 5                                    CONTUSION                   38.0
# 6                                   LACERATION                   36.0
# 7   ALL OTHER OCCUPATIONAL DISEASE INJURY, NOC                   38.0
# 8             ALL OTHER SPECIFIC INJURIES, NOC                   60.0
# 9             ALL OTHER SPECIFIC INJURIES, NOC                   14.0
# 10                                   CONTUSION                   55.0
# 11                                INFLAMMATION                   53.0
# 12                                        BURN                   37.0
# 13                              STRAIN OR TEAR                   38.0
# 14                              STRAIN OR TEAR                   42.0
# 15                              SPRAIN OR TEAR                   38.0
# 16                              STRAIN OR TEAR                   61.0
# 17                              SPRAIN OR TEAR                   54.0
# 18                                   CONTUSION                   51.0
# 19                                  LACERATION                   37.0
#
#    WCIO Part Of Body Description Zip Code Agreement Reached      WCB Decision  \
# 0                       BUTTOCKS    13662               0.0  Not Work Related
# 1                    SHOULDER(S)    14569               1.0  Not Work Related
# 2           MULTIPLE HEAD INJURY    12589               0.0  Not Work Related
# 3                            NaN      NaN               NaN               NaN
# 4                      FINGER(S)    12603               0.0  Not Work Related
# 5                    SHOULDER(S)    11772               0.0  Not Work Related
# 6                      FINGER(S)    13029               0.0  Not Work Related
# 7                    SHOULDER(S)    10305               0.0  Not Work Related
# 8                          LUNGS    14620               0.0  Not Work Related
# 9                         EYE(S)    11231               0.0  Not Work Related
# 10                         ANKLE    12550               0.0  Not Work Related
# 11                          KNEE    07649               0.0  Not Work Related
# 12                         THUMB    11106               0.0  Not Work Related
# 13                   SHOULDER(S)    10703               0.0  Not Work Related
# 14               LOWER BACK AREA    13108               0.0  Not Work Related
# 15                   SHOULDER(S)    11779               0.0  Not Work Related
# 16       ABDOMEN INCLUDING GROIN    11208               0.0  Not Work Related
# 17                     LOWER LEG    11788               0.0  Not Work Related
# 18                           HIP    11779               0.0  Not Work Related
# 19                         THUMB    11791               0.0  Not Work Related
#
#     Number of Dependents
# 0                    1.0
# 1                    4.0
# 2                    6.0
# 3                    NaN
# 4                    1.0
# 5                    5.0
# 6                    1.0
# 7                    6.0
# 8                    6.0
# 9                    6.0
# 10                   1.0
# 11                   3.0
# 12                   3.0
# 13                   4.0
# 14                   4.0
# 15                   6.0
# 16                   1.0
# 17                   6.0
# 18                   3.0
# 19                   4.0
#
# [20 rows x 33 columns]

# %%
test.head(10)
# Out:
#   Accident Date  Age at Injury Alternative Dispute Resolution Assembly Date  \
# 0    2022-12-24             19                              N    2023-01-02
# 1    2022-11-20             19                              N    2023-01-02
# 2    2022-12-26             59                              N    2023-01-02
# 3    2022-12-28             55                              N    2023-01-02
# 4    2022-12-20             25                              N    2023-01-02
# 5    2022-12-28             36                              N    2023-01-02
# 6    2022-12-22             19                              N    2023-01-02
# 7    2022-12-13             43                              N    2023-01-02
# 8    2022-12-28             40                              N    2023-01-02
# 9    2022-11-01             48                              N    2023-01-02
#
#   Attorney/Representative  Average Weekly Wage  Birth Year    C-2 Date  \
# 0                       N                  NaN      2003.0  2023-01-02
# 1                       N                  NaN      2003.0  2023-01-02
# 2                       N                 0.00      1963.0  2022-12-31
# 3                       N                 0.00         0.0  2023-01-02
# 4                       N                 0.00      1997.0  2022-12-31
# 5                       N                 0.00      1986.0  2023-01-02
# 6                       N               688.20      2003.0  2022-12-30
# 7                       N                 0.00         0.0  2023-01-02
# 8                       N                 0.00      1982.0  2022-12-31
# 9                       Y              1180.74      1974.0  2023-01-02
#
#      C-3 Date                    Carrier Name  ... Medical Fee Region  \
# 0         NaN       INDEMNITY INSURANCE CO OF  ...                 IV
# 1         NaN         A I U INSURANCE COMPANY  ...                 IV
# 2         NaN       AMGUARD INSURANCE COMPANY  ...                III
# 3         NaN     INDEMNITY INS. OF N AMERICA  ...                 IV
# 4         NaN      NEW HAMPSHIRE INSURANCE CO  ...                 IV
# 5         NaN           NYC TRANSIT AUTHORITY  ...                III
# 6         NaN       WAL-MART ASSOCIATES, INC.  ...                  I
# 7         NaN         ERIE INSURANCE CO OF NY  ...                  I
# 8         NaN  STARR INDEMNITY & LIABILITY CO  ...                 IV
# 9  2023-01-09            STATE INSURANCE FUND  ...                  I
#
#    OIICS Nature of Injury Description WCIO Cause of Injury Code  \
# 0                                 NaN                      31.0
# 1                                 NaN                      75.0
# 2                                 NaN                      68.0
# 3                                 NaN                      25.0
# 4                                 NaN                      79.0
# 5                                 NaN                      90.0
# 6                                 NaN                      56.0
# 7                                 NaN                      27.0
# 8                                 NaN                      87.0
# 9                                 NaN                      25.0
#
#       WCIO Cause of Injury Description WCIO Nature of Injury Code  \
# 0              FALL, SLIP OR TRIP, NOC                       10.0
# 1             FALLING OR FLYING OBJECT                       10.0
# 2                    STATIONARY OBJECT                       49.0
# 3     FROM DIFFERENT LEVEL (ELEVATION)                       10.0
# 4       OBJECT BEING LIFTED OR HANDLED                       40.0
# 5  OTHER THAN PHYSICAL CAUSE OF INJURY                       77.0
# 6                              LIFTING                       49.0
# 7         FROM LIQUID OR GREASE SPILLS                       49.0
# 8      FOREIGN MATTER (BODY) IN EYE(S)                       25.0
# 9     FROM DIFFERENT LEVEL (ELEVATION)                       49.0
#
#   WCIO Nature of Injury Description WCIO Part Of Body Code  \
# 0                         CONTUSION                   54.0
# 1                         CONTUSION                   10.0
# 2                    SPRAIN OR TEAR                   62.0
# 3                         CONTUSION                   53.0
# 4                        LACERATION                   37.0
# 5                     MENTAL STRESS                   66.0
# 6                    SPRAIN OR TEAR                   38.0
# 7                    SPRAIN OR TEAR                   53.0
# 8                      FOREIGN BODY                   14.0
# 9                    SPRAIN OR TEAR                   38.0
#
#    WCIO Part Of Body Description  Zip Code Number of Dependents
# 0                      LOWER LEG     10466                    1
# 1           MULTIPLE HEAD INJURY     11691                    1
# 2                       BUTTOCKS     10604                    0
# 3                           KNEE     11411                    6
# 4                          THUMB     11212                    5
# 5             NO PHYSICAL INJURY     10941                    4
# 6                    SHOULDER(S)     14131                    6
# 7                           KNEE     13357                    4
# 8                         EYE(S)     11735                    3
# 9                    SHOULDER(S)     14720                    0
#
# [10 rows x 30 columns]

# %%
train.shape
# Out:
# (593471, 33)

# %%
test.shape
# Out:
# (387975, 30)

# %%
columns_name = train.columns
columns_name
# Out:
# Index(['Accident Date', 'Age at Injury', 'Alternative Dispute Resolution',
#        'Assembly Date', 'Attorney/Representative', 'Average Weekly Wage',
#        'Birth Year', 'C-2 Date', 'C-3 Date', 'Carrier Name', 'Carrier Type',
#        'Claim Identifier', 'Claim Injury Type', 'County of Injury',
#        'COVID-19 Indicator', 'District Name', 'First Hearing Date', 'Gender',
#        'IME-4 Count', 'Industry Code', 'Industry Code Description',
#        'Medical Fee Region', 'OIICS Nature of Injury Description',
#        'WCIO Cause of Injury Code', 'WCIO Cause of Injury Description',
#        'WCIO Nature of Injury Code', 'WCIO Nature of Injury Description',
#        'WCIO Part Of Body Code', 'WCIO Part Of Body Description', 'Zip Code',
#        'Agreement Reached', 'WCB Decision', 'Number of Dependents'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['Accident Date', 'Age at Injury', 'Alternative Dispute Resolution',
#        'Assembly Date', 'Attorney/Representative', 'Average Weekly Wage',
#        'Birth Year', 'C-2 Date', 'C-3 Date', 'Carrier Name', 'Carrier Type',
#        'Claim Identifier', 'County of Injury', 'COVID-19 Indicator',
#        'District Name', 'First Hearing Date', 'Gender', 'IME-4 Count',
#        'Industry Code', 'Industry Code Description', 'Medical Fee Region',
#        'OIICS Nature of Injury Description', 'WCIO Cause of Injury Code',
#        'WCIO Cause of Injury Description', 'WCIO Nature of Injury Code',
#        'WCIO Nature of Injury Description', 'WCIO Part Of Body Code',
#        'WCIO Part Of Body Description', 'Zip Code', 'Number of Dependents'],
#       dtype='object')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 593471 entries, 0 to 593470
# Data columns (total 33 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Accident Date                       570337 non-null  object
#  1   Age at Injury                       574026 non-null  float64
#  2   Alternative Dispute Resolution      574026 non-null  object
#  3   Assembly Date                       593471 non-null  object
#  4   Attorney/Representative             574026 non-null  object
#  5   Average Weekly Wage                 545375 non-null  float64
#  6   Birth Year                          544948 non-null  float64
#  7   C-2 Date                            559466 non-null  object
#  8   C-3 Date                            187245 non-null  object
#  9   Carrier Name                        574026 non-null  object
#  10  Carrier Type                        574026 non-null  object
#  11  Claim Identifier                    593471 non-null  int64
#  12  Claim Injury Type                   574026 non-null  object
#  13  County of Injury                    574026 non-null  object
#  14  COVID-19 Indicator                  574026 non-null  object
#  15  District Name                       574026 non-null  object
#  16  First Hearing Date                  150798 non-null  object
#  17  Gender                              574026 non-null  object
#  18  IME-4 Count                         132803 non-null  float64
#  19  Industry Code                       564068 non-null  float64
#  20  Industry Code Description           564068 non-null  object
#  21  Medical Fee Region                  574026 non-null  object
#  22  OIICS Nature of Injury Description  0 non-null       float64
#  23  WCIO Cause of Injury Code           558386 non-null  float64
#  24  WCIO Cause of Injury Description    558386 non-null  object
#  25  WCIO Nature of Injury Code          558369 non-null  float64
#  26  WCIO Nature of Injury Description   558369 non-null  object
#  27  WCIO Part Of Body Code              556944 non-null  float64
#  28  WCIO Part Of Body Description       556944 non-null  object
#  29  Zip Code                            545389 non-null  object
#  30  Agreement Reached                   574026 non-null  float64
#  31  WCB Decision                        574026 non-null  object
#  32  Number of Dependents                574026 non-null  float64
# dtypes: float64(11), int64(1), object(21)
# memory usage: 149.4+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 387975 entries, 0 to 387974
# Data columns (total 30 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   Accident Date                       385531 non-null  object
#  1   Age at Injury                       387975 non-null  int64
#  2   Alternative Dispute Resolution      387975 non-null  object
#  3   Assembly Date                       387975 non-null  object
#  4   Attorney/Representative             387975 non-null  object
#  5   Average Weekly Wage                 368771 non-null  float64
#  6   Birth Year                          368505 non-null  float64
#  7   C-2 Date                            378841 non-null  object
#  8   C-3 Date                            85216 non-null   object
#  9   Carrier Name                        387975 non-null  object
#  10  Carrier Type                        387975 non-null  object
#  11  Claim Identifier                    387975 non-null  int64
#  12  County of Injury                    387975 non-null  object
#  13  COVID-19 Indicator                  387975 non-null  object
#  14  District Name                       387975 non-null  object
#  15  First Hearing Date                  43028 non-null   object
#  16  Gender                              387975 non-null  object
#  17  IME-4 Count                         35249 non-null   float64
#  18  Industry Code                       380239 non-null  float64
#  19  Industry Code Description           380239 non-null  object
#  20  Medical Fee Region                  387975 non-null  object
#  21  OIICS Nature of Injury Description  0 non-null       float64
#  22  WCIO Cause of Injury Code           377627 non-null  float64
#  23  WCIO Cause of Injury Description    377627 non-null  object
#  24  WCIO Nature of Injury Code          377415 non-null  float64
#  25  WCIO Nature of Injury Description   377415 non-null  object
#  26  WCIO Part Of Body Code              378426 non-null  float64
#  27  WCIO Part Of Body Description       378426 non-null  object
#  28  Zip Code                            368633 non-null  object
#  29  Number of Dependents                387975 non-null  int64
# dtypes: float64(8), int64(3), object(19)
# memory usage: 88.8+ MB

# %%
train.describe(include ='all')
# Out:
#        Accident Date  Age at Injury Alternative Dispute Resolution  \
# count         570337  574026.000000                         574026
# unique          5539            NaN                              3
# top       2020-03-01            NaN                              N
# freq            1245            NaN                         571412
# mean             NaN      42.114270                            NaN
# std              NaN      14.256432                            NaN
# min              NaN       0.000000                            NaN
# 25%              NaN      31.000000                            NaN
# 50%              NaN      42.000000                            NaN
# 75%              NaN      54.000000                            NaN
# max              NaN     117.000000                            NaN
#
#        Assembly Date Attorney/Representative  Average Weekly Wage  \
# count         593471                  574026         5.453750e+05
# unique          1096                       2                  NaN
# top       2020-03-06                       N                  NaN
# freq            1422                  392291                  NaN
# mean             NaN                     NaN         4.910883e+02
# std              NaN                     NaN         6.092918e+03
# min              NaN                     NaN         0.000000e+00
# 25%              NaN                     NaN         0.000000e+00
# 50%              NaN                     NaN         0.000000e+00
# 75%              NaN                     NaN         8.410000e+02
# max              NaN                     NaN         2.828079e+06
#
#            Birth Year    C-2 Date    C-3 Date          Carrier Name  ...  \
# count   544948.000000      559466      187245                574026  ...
# unique            NaN        2475        1648                  2046  ...
# top               NaN  2021-05-11  2021-04-21  STATE INSURANCE FUND  ...
# freq              NaN        1847         350                111144  ...
# mean      1886.767604         NaN         NaN                   NaN  ...
# std        414.644423         NaN         NaN                   NaN  ...
# min          0.000000         NaN         NaN                   NaN  ...
# 25%       1965.000000         NaN         NaN                   NaN  ...
# 50%       1977.000000         NaN         NaN                   NaN  ...
# 75%       1989.000000         NaN         NaN                   NaN  ...
# max       2018.000000         NaN         NaN                   NaN  ...
#
#        WCIO Cause of Injury Code  WCIO Cause of Injury Description  \
# count              558386.000000                            558386
# unique                       NaN                                74
# top                          NaN                           LIFTING
# freq                         NaN                             46610
# mean                   54.381143                               NaN
# std                    25.874281                               NaN
# min                     1.000000                               NaN
# 25%                    31.000000                               NaN
# 50%                    56.000000                               NaN
# 75%                    75.000000                               NaN
# max                    99.000000                               NaN
#
#        WCIO Nature of Injury Code WCIO Nature of Injury Description  \
# count               558369.000000                            558369
# unique                        NaN                                56
# top                           NaN                    STRAIN OR TEAR
# freq                          NaN                            153373
# mean                    41.013839                               NaN
# std                     22.207521                               NaN
# min                      1.000000                               NaN
# 25%                     16.000000                               NaN
# 50%                     49.000000                               NaN
# 75%                     52.000000                               NaN
# max                     91.000000                               NaN
#
#        WCIO Part Of Body Code WCIO Part Of Body Description Zip Code  \
# count           556944.000000                        556944   545389
# unique                    NaN                            54    10060
# top                       NaN               LOWER BACK AREA    11236
# freq                      NaN                         51862     3302
# mean                39.738146                           NaN      NaN
# std                 22.365940                           NaN      NaN
# min                 -9.000000                           NaN      NaN
# 25%                 33.000000                           NaN      NaN
# 50%                 38.000000                           NaN      NaN
# 75%                 53.000000                           NaN      NaN
# max                 99.000000                           NaN      NaN
#
#        Agreement Reached      WCB Decision  Number of Dependents
# count      574026.000000            574026         574026.000000
# unique               NaN                 1                   NaN
# top                  NaN  Not Work Related                   NaN
# freq                 NaN            574026                   NaN
# mean            0.046665               NaN              3.006559
# std             0.210921               NaN              2.000801
# min             0.000000               NaN              0.000000
# 25%             0.000000               NaN              1.000000
# 50%             0.000000               NaN              3.000000
# 75%             0.000000               NaN              5.000000
# max             1.000000               NaN              6.000000
#
# [11 rows x 33 columns]

# %%
test.describe(include = 'all')
# Out:
#        Accident Date  Age at Injury Alternative Dispute Resolution  \
# count         385531  387975.000000                         387975
# unique          3438            NaN                              3
# top       2024-01-16            NaN                              N
# freq            1263            NaN                         386314
# mean             NaN      41.414944                            NaN
# std              NaN      14.501056                            NaN
# min              NaN       0.000000                            NaN
# 25%              NaN      30.000000                            NaN
# 50%              NaN      40.000000                            NaN
# 75%              NaN      53.000000                            NaN
# max              NaN     114.000000                            NaN
#
#        Assembly Date Attorney/Representative  Average Weekly Wage  \
# count         387975                  387975         3.687710e+05
# unique           434                       2                  NaN
# top       2023-09-21                       N                  NaN
# freq            1789                  306476                  NaN
# mean             NaN                     NaN         1.833438e+02
# std              NaN                     NaN         3.542310e+03
# min              NaN                     NaN         0.000000e+00
# 25%              NaN                     NaN         0.000000e+00
# 50%              NaN                     NaN         0.000000e+00
# 75%              NaN                     NaN         0.000000e+00
# max              NaN                     NaN         1.950317e+06
#
#            Birth Year    C-2 Date    C-3 Date          Carrier Name  ...  \
# count   368505.000000      378841       85216                387975  ...
# unique            NaN        1048         626                  1598  ...
# top               NaN  2023-10-11  2023-10-04  STATE INSURANCE FUND  ...
# freq              NaN        1687         341                 66189  ...
# mean      1875.383466         NaN         NaN                   NaN  ...
# std        444.659075         NaN         NaN                   NaN  ...
# min          0.000000         NaN         NaN                   NaN  ...
# 25%       1967.000000         NaN         NaN                   NaN  ...
# 50%       1980.000000         NaN         NaN                   NaN  ...
# 75%       1992.000000         NaN         NaN                   NaN  ...
# max       2019.000000         NaN         NaN                   NaN  ...
#
#        Medical Fee Region  OIICS Nature of Injury Description  \
# count              387975                                 0.0
# unique                  5                                 NaN
# top                    IV                                 NaN
# freq               182276                                 NaN
# mean                  NaN                                 NaN
# std                   NaN                                 NaN
# min                   NaN                                 NaN
# 25%                   NaN                                 NaN
# 50%                   NaN                                 NaN
# 75%                   NaN                                 NaN
# max                   NaN                                 NaN
#
#        WCIO Cause of Injury Code        WCIO Cause of Injury Description  \
# count              377627.000000                                  377627
# unique                       NaN                                      74
# top                          NaN  FELLOW WORKER, PATIENT OR OTHER PERSON
# freq                         NaN                                   33293
# mean                   53.335678                                     NaN
# std                    26.176833                                     NaN
# min                     1.000000                                     NaN
# 25%                    29.000000                                     NaN
# 50%                    56.000000                                     NaN
# 75%                    74.000000                                     NaN
# max                    99.000000                                     NaN
#
#        WCIO Nature of Injury Code WCIO Nature of Injury Description  \
# count               377415.000000                            377415
# unique                        NaN                                56
# top                           NaN                    STRAIN OR TEAR
# freq                          NaN                            108326
# mean                    38.373674                               NaN
# std                     20.966100                               NaN
# min                      1.000000                               NaN
# 25%                     10.000000                               NaN
# 50%                     43.000000                               NaN
# 75%                     52.000000                               NaN
# max                     91.000000                               NaN
#
#        WCIO Part Of Body Code  WCIO Part Of Body Description  Zip Code  \
# count           378426.000000                         378426    368633
# unique                    NaN                             51      6276
# top                       NaN                       MULTIPLE     11368
# freq                      NaN                          67465      2068
# mean                31.516109                            NaN       NaN
# std                 23.359950                            NaN       NaN
# min                 -9.000000                            NaN       NaN
# 25%                 15.000000                            NaN       NaN
# 50%                 36.000000                            NaN       NaN
# 75%                 51.000000                            NaN       NaN
# max                 99.000000                            NaN       NaN
#
#        Number of Dependents
# count         387975.000000
# unique                  NaN
# top                     NaN
# freq                    NaN
# mean               3.000284
# std                1.997982
# min                0.000000
# 25%                1.000000
# 50%                3.000000
# 75%                5.000000
# max                6.000000
#
# [11 rows x 30 columns]

# %%
print(train.duplicated().value_counts())
print(test.duplicated().value_counts())
# Out:
# False    593471
# Name: count, dtype: int64
# False    387975
# Name: count, dtype: int64

# %%
train['Claim Injury Type'].value_counts()
# Out:
# Claim Injury Type
# 2. NON-COMP        291078
# 4. TEMPORARY       148507
# 3. MED ONLY         68906
# 5. PPD SCH LOSS     48280
# 1. CANCELLED        12477
# 6. PPD NSL           4211
# 8. DEATH              470
# 7. PTD                 97
# Name: count, dtype: int64

# %% [markdown]
# <hr>
# <a class="anchor" id="datapreprocessing">
#
# # 4. Data Pre-Processing
#
# </a>

# %%
train.set_index('Claim Identifier', inplace=True) #set Claim Identifier as index
test.set_index('Claim Identifier', inplace=True)

# %% [markdown]
# <hr>
# <a class="anchor" id="missingvalues">
#
# ## Missing Values
#
# </a>

# %%
msno.matrix(train, labels=True, sort="descending");

# %%
# first hearing date - blank values mean it hasnt been set yet

# %%
strange_values_list = ["!","$","%","?","*","+","_","@","€"," ","{"]
train.replace(strange_values_list,np.nan, inplace=True)

# %%
train.isna().sum()
# Out:
# Accident Date                          23134
# Age at Injury                          19445
# Alternative Dispute Resolution         19445
# Assembly Date                              0
# Attorney/Representative                19445
# Average Weekly Wage                    48096
# Birth Year                             48523
# C-2 Date                               34005
# C-3 Date                              406226
# Carrier Name                           19445
# Carrier Type                           19445
# Claim Injury Type                      19445
# County of Injury                       19445
# COVID-19 Indicator                     19445
# District Name                          19445
# First Hearing Date                    442673
# Gender                                 19445
# IME-4 Count                           460668
# Industry Code                          29403
# Industry Code Description              29403
# Medical Fee Region                     19445
# OIICS Nature of Injury Description    593471
# WCIO Cause of Injury Code              35085
# WCIO Cause of Injury Description       35085
# WCIO Nature of Injury Code             35102
# WCIO Nature of Injury Description      35102
# WCIO Part Of Body Code                 36527
# WCIO Part Of Body Description          36527
# Zip Code                               48082
# Agreement Reached                      19445
# WCB Decision                           19445
# Number of Dependents                   19445
# dtype: int64

# %%
train.drop('OIICS Nature of Injury Description', inplace = True, axis = 1)

# %%
# median
# for metric columns
#fill with median as it does not get influenced by extreme outliers
for col in train.columns:
    if pd.api.types.is_numeric_dtype(train[col]): 
        median_to_fill = train[col].median()
        train[col].fillna(median_to_fill, inplace=True)

# %%
# mean

# %%
#kn

# %%
train.dropna(subset=['Claim Injury Type'], inplace=True)
train['Claim Injury Type']
# Out:
# Claim Identifier
# 5393875     2. NON-COMP
# 5393091    4. TEMPORARY
# 5393889    4. TEMPORARY
# 5393887     2. NON-COMP
# 5393863     3. MED ONLY
#                ...
# 6165265     2. NON-COMP
# 6165285     2. NON-COMP
# 6165506    4. TEMPORARY
# 6165339     2. NON-COMP
# 6165075     2. NON-COMP
# Name: Claim Injury Type, Length: 574026, dtype: object

# %%
#for non-metric columns
#replace NaN with Unknown
object_columns = train.select_dtypes(include=['object']).columns

for col in object_columns:
    train[col] = train[col].fillna('Unknown')

# %%
train.isna().sum()
# Out:
# Accident Date                        0
# Age at Injury                        0
# Alternative Dispute Resolution       0
# Assembly Date                        0
# Attorney/Representative              0
# Average Weekly Wage                  0
# Birth Year                           0
# C-2 Date                             0
# C-3 Date                             0
# Carrier Name                         0
# Carrier Type                         0
# Claim Injury Type                    0
# County of Injury                     0
# COVID-19 Indicator                   0
# District Name                        0
# First Hearing Date                   0
# Gender                               0
# IME-4 Count                          0
# Industry Code                        0
# Industry Code Description            0
# Medical Fee Region                   0
# WCIO Cause of Injury Code            0
# WCIO Cause of Injury Description     0
# WCIO Nature of Injury Code           0
# WCIO Nature of Injury Description    0
# WCIO Part Of Body Code               0
# WCIO Part Of Body Description        0
# Zip Code                             0
# Agreement Reached                    0
# WCB Decision                         0
# Number of Dependents                 0
# dtype: int64

# %%
train['Claim Injury Type Num'] = train['Claim Injury Type'].str.extract('(\d+)').astype(int)
train['Claim Injury Type Num']
# Out:
# Claim Identifier
# 5393875    2
# 5393091    4
# 5393889    4
# 5393887    2
# 5393863    3
#           ..
# 6165265    2
# 6165285    2
# 6165506    4
# 6165339    2
# 6165075    2
# Name: Claim Injury Type Num, Length: 574026, dtype: int32

# %% [markdown]
# ## Further Analysis

# %%
print('youngest person:',train['Birth Year'].max())
print('oldest injured:',train['Age at Injury'].max())
print('most dependents:',train['Number of Dependents'].max())
# Out:
# youngest person: 2018.0
# oldest injured: 117.0
# most dependents: 6.0

# %%
for i in columns_name:
    print(i)
    print(train[i].unique())
    print(train[i].value_counts())
    print('\n')
# Out:
# Accident Date
# ['2019-12-30' '2019-08-30' '2019-12-06' ... '2000-05-24' '2007-05-01'
#  '1980-05-17']
# Accident Date
# Unknown       3689
# 2020-03-01    1245
# 2020-12-18    1001
# 2022-02-07     977
# 2022-01-05     883
#               ...
# 2017-05-17       1
# 2015-05-28       1
# 2002-08-18       1
# 2017-09-01       1
# 1980-05-17       1
# Name: count, Length: 5540, dtype: int64
#
#
# Age at Injury
# [ 31.  46.  40.  61.  67.  48.  33.  55.  20.  21.  51.  62.  35.  54.
#   32.  34.  38.  30.  36.  39.  44.  56.  29.  60.  49.  50.  18.  58.
#   24.  45.  53.  52.  47.  25.  23.  22.  64.  70.  41.  69.  57.  27.
#   42.  77.  72.  19.  28.  63.  65.  59.  43.  26.  74.  66.  76.  68.
#   37.   0.  16.  71.  82.  75.  17.  78.  73.  89.  85.  84.  81.  87.
#   80.  11.  88.  79.  15.  83.  86.  90.   1.  10. 102.  94. 117.  14.
#  113.  95.  92. 104.   5.   8. 115. 110.  91.  96.  99.  12.  13.  93.
#  101.   7. 111.   9.  97. 112. 109. 100.  98. 114.]
# Age at Injury
# 31.0     14041
# 30.0     14022
# 32.0     13994
# ['Unknown' '2020-01-14' '2020-03-04' ... '2023-08-19' '2023-05-06'
#  '2023-02-04']
# C-3 Date
# Unknown       386781
# 2021-04-21       350
# 2020-02-10       347
# 2020-10-26       347
# 2020-09-23       345
#                ...
# 2019-04-04         1
# 2019-12-09         1
# 2019-03-28         1
# 2019-04-03         1
# 2019-07-03         1
# Name: count, Length: 1649, dtype: int64
#
#
# Carrier Name
# ['NEW HAMPSHIRE INSURANCE CO' 'ZURICH AMERICAN INSURANCE CO'
#  'INDEMNITY INSURANCE CO OF' ... 'MARATHON CENTRAL SCHOOL DIST'
#  'CAMBRIDGE CENTRAL SCHOOL' 'HERMON-DEKALB CENTRAL']
# Carrier Name
# STATE INSURANCE FUND            111144
# POLICE, FIRE, SANITATION         21602
# AMERICAN ZURICH INSURANCE CO     17540
# CHARTER OAK FIRE INS CO          17176
# INDEMNITY INS. OF N AMERICA      14366
#                                  ...
# LOWES HOME CENTERS INC               1
# WEST BEND MUTUAL INSURANCE           1
# LIVINGSTON-STEUBEN-                  1
# NEW YORK MUTUAL CASUALTY             1
# HERMON-DEKALB CENTRAL                1
# Name: count, Length: 2046, dtype: int64
#
#
# Carrier Type
# ['1A. PRIVATE' '2A. SIF' '4A. SELF PRIVATE' '3A. SELF PUBLIC' 'UNKNOWN'
#  '5D. SPECIAL FUND - UNKNOWN'
#  '5A. SPECIAL FUND - CONS. COMM. (SECT. 25-A)'
#  '5C. SPECIAL FUND - POI CARRIER WCB MENANDS']
# Carrier Type
# 1A. PRIVATE                                    285368
# 3A. SELF PUBLIC                                121920
# 2A. SIF                                        111144
# 4A. SELF PRIVATE                                52788
# UNKNOWN                                          1774
# 5D. SPECIAL FUND - UNKNOWN                       1023
# 5C. SPECIAL FUND - POI CARRIER WCB MENANDS          5
# 5A. SPECIAL FUND - CONS. COMM. (SECT. 25-A)         4
# Name: count, dtype: int64
#
#
# Claim Identifier
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3.1\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3.1\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3.1\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Claim Identifier'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 3
#       1 for i in columns_name:
#       2     print(i)
# ----> 3     print(train[i].unique())
#       4     print(train[i].value_counts())
#       5     print('\n')
#
# File ~\anaconda3.1\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\anaconda3.1\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Claim Identifier'

# %% [markdown]
# #### Data Categorization

# %%
numerical_cols = train.select_dtypes(include=['int64', 'float64']).columns.tolist()
 # Exclude target variable if present

categorical_cols = train.select_dtypes(include=['object']).columns.tolist()
print("Categorical columns:")
print(categorical_cols)
# Out:
# Categorical columns:
# ['Accident Date', 'Alternative Dispute Resolution', 'Assembly Date', 'Attorney/Representative', 'C-2 Date', 'C-3 Date', 'Carrier Name', 'Carrier Type', 'Claim Injury Type', 'County of Injury', 'COVID-19 Indicator', 'District Name', 'First Hearing Date', 'Gender', 'Industry Code Description', 'Medical Fee Region', 'WCIO Cause of Injury Description', 'WCIO Nature of Injury Description', 'WCIO Part Of Body Description', 'Zip Code', 'WCB Decision']

# %% [markdown]
# #### Graphical Representaion

# %%
train[numerical_cols].hist(figsize=(15, 10))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot( x= 'Claim Injury Type Num', data = train)
plt.title('Distribution of Claim Injury Type Num')
plt.show()

# %%
for col in categorical_cols:
    plt.figure(figsize=(10, 5))
    sns.countplot(data=train, x=col, order=train[col].value_counts().index)
    plt.xticks(rotation=90)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
corr_matrix = train[numerical_cols + ['Claim Injury Type Num']].corr()

plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
for col in numerical_cols:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x='Claim Injury Type Num', y=col, data=train)
    plt.title(f'{col} vs Claim Injury Type Num')
    plt.show()

# %% [markdown]
# ## Distributions

# %%
#For train
X_train_num = X_train.select_dtypes(include=np.number).set_index(X_train.index)
X_train_cat = X_train.select_dtypes(exclude=np.number).set_index(X_train.index)

# %% [markdown]
# ### Non-Metric Features

# %%
X_train_cat_2 = train[['Alternative Dispute Resolution', 'Attorney/Representative', 'Carrier Type', 'COVID-19 Indicator','District Name',
                        'Gender', 'Medical Fee Region']]

# %%
sns.set_style('ticks')
sp_rows = 2
sp_cols = ceil(len(X_train_cat_2) / sp_rows)
fig, axes = plt.subplots(sp_rows, 
                         sp_cols, 
                         figsize=(20, 25),
                         tight_layout=True
                        )
# Plot data
for ax, feat in zip(axes.flatten(), X_train_cat_2): 
    train[feat].value_counts().plot(kind='bar', ax=ax, color ='skyblue')
# Remove excess axes
for ax in axes.flatten()[len(X_train_cat_2):]:
    ax.set_axis_off()

# %% [markdown]
# ### Metric Features

# %%
sns.set_style('ticks')
sp_rows = 2
sp_cols = ceil(len(object_columns_2) / sp_rows)
fig, axes = plt.subplots(sp_rows, 
                         sp_cols, 
                         figsize=(20, 25),
                         tight_layout=True
                        )
# Plot data
for ax, feat in zip(axes.flatten(), object_columns_2): 
    train[feat].value_counts().plot(kind='bar', ax=ax, color ='skyblue')
# Remove excess axes
for ax in axes.flatten()[len(object_columns_2):]:
    ax.set_axis_off()

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# <hr>
# <a class="anchor" id="datapartition">
#
# ## Data Partition
#
# </a>

# %%
X = train.drop(['Claim Injury Type' ,'Claim Injury Type_float'], axis = 1)
y = train['Claim Injury Type_float']

# %%
X_train, X_val, y_train, y_val = train_test_split(X,y, test_size = 0.3, 
                                                  random_state = 0, 
                                                  stratify = y, 
                                                  shuffle = True)

# %%
#For train
X_train_num = X_train.select_dtypes(include=np.number).set_index(X_train.index)
X_train_cat = X_train.select_dtypes(exclude=np.number).set_index(X_train.index)

#For Validation
X_val_num = X_val.select_dtypes(include=np.number).set_index(X_val.index)
X_val_cat = X_val.select_dtypes(exclude=np.number).set_index(X_val.index)

# %%
#call function
scaler = MinMaxScaler()

#fit to training data
scaler.fit(X_train_num)

#transform the data
X_train_num_scaled = scaler.transform(X_train_num) # this will return an array

#show results
X_train_num_scaled

# %%
# Convert the array to a pandas dataframe
X_train_num_scaled = pd.DataFrame(X_train_num_scaled, columns = X_train_num.columns).set_index(X_train.index)
X_train_num_scaled

# %%
X_val_num_scaled = scaler.transform(X_val_num)
X_val_num_scaled = pd.DataFrame(X_val_num_scaled, columns = X_val_num.columns).set_index(X_val.index)
X_val_num_scaled.head(3)

# %%
from sklearn.linear_model import LogisticRegression
log_model = LogisticRegression()
